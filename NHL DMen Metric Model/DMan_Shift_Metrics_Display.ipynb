# %%
import NHL_DMan_Shift_Processor as dsp
# Out:
# /Users/bryanpeltier/Downloads/NHL DMan Evaluation Model/NHL_DMan_Shift_Processor.py:397: SyntaxWarning: invalid escape sequence '\d'
#   lambda x: re.findall('(#)(\d\d)|(#)(\d)|(-) (\d\d)|(-) (\d)', x)).astype(str

# %%
print(dsp.build_team_chart(dsp.kings_2425()))
# Out:
#   Number  Name                  Avg. Time Taken to Clear the D-Zone (Sec)    % of Shifts w/o a Successful D-Zone Clearance
#       44  Mikey Anderson                                            13.97                                            46.65
#        7  Kyle Burroughs                                             8.55                                            47.26
#       92  Brandt Clarke                                              9.78                                            44.15
#        6  Joel Edmundson                                            10.57                                            49.69
#        5  Andreas Englund                                            7.23                                            52.63
#       84  Vladislav Gavrikov                                        15.32                                            43.79
#       43  Jacob Moverare                                             6.81                                            50.56
# ...

# %%
print(dsp.build_team_chart(dsp.sharks_2425()))
# Out:
#   Number  Name                 Avg. Time Taken to Clear the D-Zone (Sec)    % of Shifts w/o a Successful D-Zone Clearance
#       38  Mario Ferraro                                            12.37                                            47.97
#       96  Jake Walman                                              13.62                                            46.14
#        4  Cody Ceci                                                14.92                                            49.16
#       26  Jack Thompson                                             9.29                                            50.09
#       37  Timothy Liljegren                                         9.42                                            46.34
#       84  Jan Rutta                                                11.7                                             52.99
#        3  Henry Thrun                                              11.31                                            53.27
