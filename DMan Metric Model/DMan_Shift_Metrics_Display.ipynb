# %%
import NHL_DMan_Shift_Processor as dsp

print(dsp.build_sharks_2425_chart())
# Out:
# /Users/bryanpeltier/Downloads/NHL DMan Evaluation Model/NHL_DMan_Shift_Processor.py:345: SyntaxWarning: invalid escape sequence '\d'
#   lambda x: re.findall('(#)(\d\d)|(#)(\d)|(-) (\d\d)|(-) (\d)', x)).astype(str
#   Number  Name                 Avg. Time Taken to Clear the D-Zone (Sec)    % of Shifts w/o a Successful D-Zone Clearance
#       38  Mario Ferraro                                            10.94                                            35.06
#       96  Jake Walman                                              11.07                                            31.6
#        4  Cody Ceci                                                13.25                                            35.83
#       26  Jack Thompson                                             7.82                                            39.74
#       37  Timothy Liljegren                                         8.06                                            31.19
# ...
